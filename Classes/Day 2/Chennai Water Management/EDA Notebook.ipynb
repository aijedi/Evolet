# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import seaborn as sns

import os
print(os.listdir("data"))

# Any results you write to the current directory are saved as output.
# Out:
# ['chennai-water-management.zip', 'chennai_reservoir_levels.csv', 'chennai_reservoir_rainfall.csv']

# %%
data1 = pd.read_csv("data/chennai_reservoir_levels.csv")
data2 = pd.read_csv("data/chennai_reservoir_rainfall.csv")

# %%
data1.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
# Date               5647 non-null object
# POONDI             5647 non-null float64
# CHOLAVARAM         5647 non-null float64
# REDHILLS           5647 non-null float64
# CHEMBARAMBAKKAM    5647 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 220.7+ KB

# %%
data2.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     0.0         0.0       0.0              0.0
# 1  02-01-2004     0.0         0.0       0.0              0.0
# 2  03-01-2004     0.0         0.0       0.0              0.0
# 3  04-01-2004     0.0         0.0       0.0              0.0
# 4  05-01-2004     0.0         0.0       0.0              0.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
# Date               5647 non-null object
# POONDI             5647 non-null float64
# CHOLAVARAM         5647 non-null float64
# REDHILLS           5647 non-null float64
# CHEMBARAMBAKKAM    5647 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 220.7+ KB

# %%
data2.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  5647.000000  5647.000000  5647.000000      5647.000000
# mean      3.364486     3.617177     3.756862         3.923862
# std      12.755029    14.078840    15.060551        16.287227
# min       0.000000     0.000000     0.000000         0.000000
# 25%       0.000000     0.000000     0.000000         0.000000
# 50%       0.000000     0.000000     0.000000         0.000000
# 75%       0.000000     0.000000     0.000000         0.000000
# max     300.000000   293.000000   320.000000       475.000000

# %%
data2.corr()
# Out:
#                    POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# POONDI           1.000000    0.711964  0.712009         0.684963
# CHOLAVARAM       0.711964    1.000000  0.904036         0.745151
# REDHILLS         0.712009    0.904036  1.000000         0.783919
# CHEMBARAMBAKKAM  0.684963    0.745151  0.783919         1.000000

# %%
f,ax = plt.subplots(figsize=(7,7))
sns.heatmap(data1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data1.shape
# Out:
# (5647, 5)

# %%
data1.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0

# %%
data1.POONDI.plot(kind = 'line', color = 'g',label = 'POONDI',linewidth=1, alpha = 0.5,grid = True,linestyle = ':')
data1.REDHILLS.plot(color = 'r',label = 'REDHILLS',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('REDHILLS AND POONDI Plot')           
plt.show()

# %%
data1.plot(kind='scatter', x='CHOLAVARAM', y='POONDI',alpha = 0.5,color = 'blue')
plt.xlabel('REDHILLS')              # label = name of label
plt.ylabel('POONDI')
plt.title('POONDI AND REDHILLS Scatter Plot')
plt.show()

# %%
data1.columns
# Out:
# Index(['Date', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], dtype='object')

# %%
df1 = data1

# %%
df1[df1['REDHILLS']==df1['REDHILLS'].min()].head()
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 223  11-08-2004     2.8         0.0       0.0              0.0
# 224  12-08-2004     2.7         0.0       0.0              0.0
# 225  13-08-2004     2.7         0.0       0.0              0.0
# 226  14-08-2004     2.7         0.0       0.0              0.0
# 227  15-08-2004     2.6         0.0       0.0              0.0

# %%
data1[data1['POONDI']==data1['POONDI'].max()]
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 371   06-01-2005  3231.0       759.0    3036.0           2973.0
# 730   31-12-2005  3231.0       764.0    3131.0           2986.0
# 731   01-01-2006  3231.0       763.0    3116.0           2986.0
# 732   02-01-2006  3231.0       762.0    3100.0           2986.0
# 733   03-01-2006  3231.0       760.0    3084.0           2986.0
# 734   04-01-2006  3231.0       759.0    3068.0           2973.0
# 735   05-01-2006  3231.0       759.0    3052.0           2973.0
# 736   06-01-2006  3231.0       759.0    3036.0           2973.0
# 737   07-01-2006  3231.0       758.0    3020.0           2973.0
# 738   08-01-2006  3231.0       757.0    3004.0           2973.0
# 739   09-01-2006  3231.0       757.0    2988.0           2973.0
# 740   10-01-2006  3231.0       757.0    2972.0           2973.0
# 741   11-01-2006  3231.0       755.0    2956.0           2973.0
# 742   12-01-2006  3231.0       754.0    2940.0           2960.0
# ...

# %%
data1.POONDI.plot(kind = 'hist',bins = 500,figsize = (10,10))
plt.show()

# %%
data1.REDHILLS.plot(kind = 'hist',bins = 500,figsize = (10,10))
plt.show()

# %%
data1.POONDI.plot(kind = 'line', color = 'g',label = 'POONDI',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data1.REDHILLS.plot(color = 'r',label = 'REDHILLS',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('REDHILLS AND POONDI Plot')           
plt.show()
